# %% [markdown]
# # Data Visualization
# In a world that we surrounded by data, understanding them is one of the requirements to live on. Visualization comes to our aid at that point to helps us to understand the any amount of data.
#
# - Data visualization is a field of study concerned with the depiction of data graphically.
#
# - Data visualization utilizes statistical graphics, charts, and other techniques to convey information efficiently; while numerical data can be encoded using dots, lines and bars, to name a few.
#
# - Most of the visualization concepts had been found even before the computer age which began in mid-1900s.
#
# -  Bottomline: Data visualization has nothing to do with computing at all, but is connected to computers in ways of presenting & manipulating data.
#
# - It's crucial to display data correctly; thus it's best to avoid from listing the years unordered, using unnecessary colors or not starting the table from 0 unless needed.
#
# ![descriptive_and_inferential.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Tufte’s 6 Principles for Graphical Integrity
#
# Tufte suggests six fundamental principles of design: show comparisons, show causality, use multivariate data, completely integrate modes (like text, images, numbers), establish credibility, and focus on content. Each should be geared towards fully embracing the goals you defined for a given data display. For each principle, we outline examples of how to apply it to improve your visualizations.
#
# 1. Comparisons:  Show data by comparisons (bar charts and the like) to depict contrasts and differences between dependent variables.
#
# 2. Causality:  Demonstrate how one or more independent variables impact or influence dependent variables.
#
# 3. Multivariate: Various data are combined so an audience can easily interpret an otherwise complex narrative.
#
# 4. Integration:  Utilize various modes of information (texts, maps, calculations, diagrams, etc.), to show evidence of source data-to-findings.
#
# 5. Documentation:  For credibility, include attribution, detailed titles, and measurements (scales).
#
# 6. Context: Describe or depict the before and after state. Show trend lines to hint at results in the future.
#
# _[Source: International Service Design Institute](https://internationalservicedesigninstitute.com/tuftes-6-principles-graphical-integrity-adopted-service-design/)_

# %% [markdown]
# # Getting & Investigating the Data

# %% [markdown]
# **In** this section, we will be using Diamonds dataset which contains the information about diamonds.
#
# Dataset has 10 columns which are:
# - **carat:** weight of the diamond (0.2--5.01)
# - **cut:** quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# 1.   Liste öğesi
# 2.   Liste öğesi
#
#
# - **color:**	diamond colour, from J (worst) to D (best)
# - **clarity:** a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - **depth:** total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# - **table:** width of top of diamond relative to widest point (43--95)
# - **price:** price in US dollars (\$326--\$18,823)
# - **x:** length in mm (0--10.74)
# - **y:** width in mm (0--58.9)
# - **z:** depth in mm (0--31.8)
#
#
# ---
#
# ***For further information about this dataset, you can visit: https://www.kaggle.com/shivam2503/diamonds***

# %%
# importing libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from pandas.api.types import CategoricalDtype

# Setting the plot size
sns.set(rc={'figure.figsize':(13, 10)})

# %%
# Load Diamonds Dataset from seaborn library
df_diamonds=sns.load_dataset("diamonds")
df_diamonds.head()  # by default, displays the first 5 rows of a dataset
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df_diamonds.info()  # info method prints information of dtype and columns, non-null values and memory usage of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df_diamonds.columns  # prints the name of the columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df_diamonds["cut"].unique()  # returns unique values of a series object unsorted
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']

# %%
df_diamonds["cut"].value_counts()  # returns the frequency of a value in a series object
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df_diamonds["cut"]  # prints the information stored in a column
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %% [markdown]
# # Graph Types

# %% [markdown]
# ## Bar Graphs
#
# - It's used for plotting histograms of bucketed numeric values in order to visually investigate how the values are distributed, and for showing quantity fluctuation of a discrete group of items.

# %% [markdown]
# ### Horizontal Bar Plot

# %%
'''
the letter 'h' at the end of the method "barh()" stands for "horizontal"
set_title() is a function of Matplotlib library
'''
df_diamonds["cut"].value_counts().plot.barh().set_title("Class Frequencies of the Cut Variable")
# Out:
# Text(0.5, 1.0, 'Class Frequencies of the Cut Variable')

# %% [markdown]
# ### Vertical Bar Plot

# %%
'''
set_title() is a function of Matplotlib library
'''
df_diamonds["cut"].value_counts().plot.bar().set_title("Class Frequencies of the Cut Variable")
# Out:
# Text(0.5, 1.0, 'Class Frequencies of the Cut Variable')

# %%
'''
You can also customize the plot style
'''
sns.barplot(x="cut", y=df_diamonds["cut"].index,data=df_diamonds, color = 'purple').set_title("Cut Density")
# Out:
# Text(0.5, 1.0, 'Cut Density')

# %% [markdown]
# ###Grouped Bar Chart
#
# - It's used when the aim is to show subgroups of one of the variables that comprises bar chart
#
# - Plots conditional distributions with hue mapping of another variable
#
# - The colors and their ordering are always consistent with each other

# %%
'''
You can indicate more than one categorical data on a plot. 
Be careful about the usage of inputs that indicates categorical data such as hue, size. You must use
categorical data column with them.
'''
sns.barplot(x="cut",
            y="price",
            hue="color",
            data=df_diamonds)
plt.title("Cut - Price - Color")
# Out:
# Text(0.5, 1.0, 'Cut - Price - Color')

# %%
sns.barplot(x="cut",
            y="price",
            hue="clarity",
            data=df_diamonds)
plt.title("Cut - Price - Clarity")
# Out:
# Text(0.5, 1.0, 'Cut - Price - Clarity')

# %%
'''
If you use numerical column for hue or size instead of a categorical column, 
you will get meaningless plot as shown below
'''
sns.barplot(x="cut",
            y="price",
            hue="carat",
            data=df_diamonds)
plt.title("Cut - Price - Clarity")
# Out:
# Text(0.5, 1.0, 'Cut - Price - Clarity')

# %% [markdown]
# ## Pie Chart

# %%
df_diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df_diamonds.groupby('cut').sum().plot.pie(y='price', autopct="%.1f%%", ylabel="", legend=False, figsize=(10,10))

# %% [markdown]
# ## Scatter Plot

# %%
cols = ["x", "y", "z"]
for col in cols:
  plt.figure(figsize=(10, 10))
  sns.scatterplot(x=col, y="price", data=df_diamonds)
  plt.show()

# %% [markdown]
# ## Histogram
#
# - The histogram is a diagram in which data is classified into buckets based on the number of bins given as a parameter
#
# - histplot() of Seaborn library assigns the number of bins automatically unless it's specified

# %%
sns.histplot(df_diamonds["price"], 
             kde=True)  # kde = kernel density estimation  # bins = "auto"

# %%
sns.histplot(df_diamonds["price"], bins=100, kde=True)  # bins is set to 100, not auto

# %%
sns.histplot(df_diamonds["price"])  # the line is not visible, kde is set to False by default

# %%
# displays only the line depicting the density 
sns.kdeplot(df_diamonds["price"])

# %%
sns.histplot(df_diamonds["price"], 
             kde=False)

# %%
sns.histplot(df_diamonds["price"], 
             bins=100, 
             kde=True)

# %% [markdown]
# ## Joint Plot
#
# - A jointplot comprises of 2 histograms of the given variables and 1 scatterplot representing their correlation, by default.
#
# - By modifying the parameters, one can also use KDE plot instead of a scatterplot as well.

# %%
sns.jointplot(x="price", y=df_diamonds["carat"], data=df_diamonds)

# %% [markdown]
# ## Catplot
#
# - Categorical Plot is used for visualizing the scattering of a numerical variable corresponding to the elements of a categorical variable

# %%
sns.catplot(x="cut", y="price", data=df_diamonds)
plt.title("Cut - Price")
# Out:
# Text(0.5, 1.0, 'Cut - Price')

# %%
(sns
.catplot(x="cut",
         y="price",
         hue="color",
         kind="point",
         data=df_diamonds))
plt.title('Cut - Price - Color')
# Out:
# Text(0.5, 1.0, 'Cut - Price - Color')

# %% [markdown]
# ###KDE Plot (Kernel Density Estimate)
#
# - KDE Plot is used for visualizing the Probability Density of a continuous variable
#
# - Multiple plots can also be displayed in a single graph

# %%
sns.kdeplot(df_diamonds["price"], shade=True)  # With shade=True, one can fill the space staying under the line

# %%
# Investigate whiich value of a chosen categorical column affects how the distribution
(sns
 .FacetGrid(df_diamonds,
            hue="cut", 
            height=5,
            xlim = (0, 10000))
.map(sns.kdeplot, "price", shade=True)
.add_legend())
plt.title('Cut - Price')
# Out:
# Text(0.5, 1.0, 'Cut - Price')

# %%
(sns
.FacetGrid(df_diamonds,
          hue="color",
          height=5,
          xlim = (0, 10000))
.map(sns.kdeplot,"price",shade=True)
.add_legend())
plt.title('Color - Price')
# Out:
# Text(0.5, 1.0, 'Color - Price')

# %% [markdown]
# ###Correlation Matrix
#
# - A correlation heatmap uses colored cells to show a 2D correlation matrix (table) between two columns
#
# - In terms of correlation, while 1 represents a strong positive correlation between two columns, -1 represents a strong negative correlation between them
#
# - It's a better method to choose which columns to perform bivariate analysis on accordingly with the values given in the correlation matrix

# %%
plt.title('Correlation Matrix')
sns.heatmap(df_diamonds.corr(), annot=True)  # heatmap() from sns library is used to plot the correlation matrix

# %%
df_diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %% [markdown]
# ## Review of Plots

# %% [markdown]
# Let's create our own dataset

# %% [markdown]
# ###Creation of Dataset

# %%
s1={"characters":["Obi-Wan Kenobi","Han Solo","Leia Organa","Luke Skywalker","Darth Vader","Anakin Skywalker","Count Dooku"],"sword":["Blue","-","-","Green","Red","Blue","Red"]}
s2={"characters":["Obi-Wan Kenobi","Han Solo","Leia Organa","Luke Skywalker","Darth Vader","Anakin Skywalker","Count Dooku"],"connection":["Republican","Rebels","Rebels","Rebels","Empire","Republican","Rebels"]}
s3={"characters":["Obi-Wan Kenobi","Han Solo","Leia Organa","Luke Skywalker","Darth Vader","Anakin Skywalker","Count Dooku"],"age":[38,29,19,19,42,22,83]}
s4={"characters":["Obi-Wan Kenobi","Han Solo","Leia Organa","Luke Skywalker","Darth Vader","Anakin Skywalker","Count Dooku"],"height":[180,174,165,175,203,183,185]}
s5={"connection":["Republican","Separatist","Rebels","Empire"],"master":["Yoda","Palpatine","Mon Mothma","Palpatine"]}
s6={"connection":["Republican","Separatist","Rebels","Empire"],"side":["Good","Bad","Good","Bad"]}

# %%
d1=pd.DataFrame(s1)
d2=pd.DataFrame(s2)
d3=pd.DataFrame(s3)
d4=pd.DataFrame(s4)
d5=pd.DataFrame(s5)
d6=pd.DataFrame(s6)

# %%
df_m1=pd.merge(d1,d2)
df_m2=pd.merge(df_m1,d3)
df_m3=pd.merge(df_m2,d4)
df_m4=pd.merge(df_m3,d5)
df_sw=pd.merge(df_m4,d6)

# %%
df_sw
# Out:
#          characters  sword  connection  age  height      master  side
# 0    Obi-Wan Kenobi   Blue  Republican   38     180        Yoda  Good
# 1  Anakin Skywalker   Blue  Republican   22     183        Yoda  Good
# 2          Han Solo      -      Rebels   29     174  Mon Mothma  Good
# 3       Leia Organa      -      Rebels   19     165  Mon Mothma  Good
# 4    Luke Skywalker  Green      Rebels   19     175  Mon Mothma  Good
# 5       Count Dooku    Red      Rebels   83     185  Mon Mothma  Good
# 6       Darth Vader    Red      Empire   42     203   Palpatine   Bad

# %% [markdown]
# ### Statistical Description of The Data

# %%
'''
object columns are categorical columns
int64 columns are numerical columns
'''
df_sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   characters  7 non-null      object
#  1   sword       7 non-null      object
#  2   connection  7 non-null      object
#  3   age         7 non-null      int64
#  4   height      7 non-null      int64
#  5   master      7 non-null      object
#  6   side        7 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 448.0+ bytes

# %%
categorical_columns = df_sw.select_dtypes(["object"]).columns

# %%
for col in categorical_columns:
  df_sw[col] = df_sw[col].astype("category")

# %%
df_sw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   characters  7 non-null      category
#  1   sword       7 non-null      category
#  2   connection  7 non-null      category
#  3   age         7 non-null      int64
#  4   height      7 non-null      int64
#  5   master      7 non-null      category
#  6   side        7 non-null      category
# dtypes: category(5), int64(2)
# memory usage: 1.0 KB

# %%
df_sw.describe().T
# Out:
#         count        mean        std    min    25%    50%    75%    max
# age       7.0   36.000000  22.627417   19.0   20.5   29.0   40.0   83.0
# height    7.0  180.714286  11.870331  165.0  174.5  180.0  184.0  203.0

# %%
df_sw.groupby("side")["age"].mean()
# Out:
# side
# Bad     42
# Good    35
# Name: age, dtype: int64

# %%
df_sw.groupby("sword")["age"].mean()
# Out:
# sword
# -        24.0
# Blue     30.0
# Green    19.0
# Red      62.5
# Name: age, dtype: float64

# %%
df_sw.groupby("sword")["age"].std()
# Out:
# sword
# -         7.071068
# Blue     11.313708
# Green          NaN
# Red      28.991378
# Name: age, dtype: float64

# %% [markdown]
# ### Visualization of Data

# %%
sns.barplot(x="side",
            y="age",
            hue="connection",
            data=df_sw)
plt.title("Side - Connection - Age")
# Out:
# Text(0.5, 1.0, 'Side - Connection - Age')

# %%
sns.kdeplot(df_sw["age"], shade=True)  # With shade=True, one can fill the space staying under the line

# %%
(sns
.FacetGrid(df_sw,
          hue="sword",
          height=5)
.map(sns.kdeplot,"age",shade=True)
.add_legend())
plt.title('Effect of sword color on age distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Effect of sword color on age distribution')

# %%
(sns
.FacetGrid(df_sw,
          hue="master",
          height=5)
.map(sns.kdeplot,"age",shade=True)
.add_legend())
plt.title('Effect of master on age distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Effect of master on age distribution')

# %%
plt.title('Correlation Matrix')
sns.heatmap(df_sw.corr(), annot=True)  # heatmap() from sns library is used to plot the correlation matrix

# %% [markdown]
# ## Data Preprocessing
#
# - In general, the dataset coming directly from a source is raw, in other words, it's filled with inconsistencies, wrongly-typed values, NA values, etc.
#
# - In such cases, applying data preprocessing is a must before training the model in further steps
#
# - The methods of improving a dataset often involve discarding some records and replacing them with meaningful values, to name a few
#
# - Let's have a more in-depth look at the steps of data preprocessing

# %%
# !cp /content/drive/MyDrive/VeriAnalizi/Datasets/airbnb_nyc_final.csv -r /content

# %%
# importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(20, 10)})

# %% [markdown]
# ### Loading and Exploring the DataFrame
#
# - Having loaded the dataset, to gain a better understanding of the values, it's of vital to obtain simple statistics regarding the columns

# %%
df = pd.read_csv("airbnb_nyc_final.csv", delimiter=",", encoding="utf-8")  # airbnb_nyc_final.csv has been imported as a dataframe 
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (11,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
#
# [5 rows x 16 columns]

# %%
df.shape  # gives the number of dimensions in an array
# Out:
# (48895, 16)

# %%
df.size  # gives the size of the array which is equal to shape[0] * shape[1]
# Out:
# 782320

# %%
df.columns  # prints the column names of the dataframe
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'date', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
df.info()  # shows the non-null counts and dtypes of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48894 non-null  object
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  object
#  7   longitude                       48895 non-null  object
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  object
#  10  minimum_nights                  48895 non-null  object
#  11  number_of_reviews               48895 non-null  object
# ...

# %%
df.describe()  # in this case, it returns only the id column because all other columns' types are object
# Out:
#                  id
# count  4.889500e+04
# mean   1.901714e+07
# std    1.098311e+07
# min    2.539000e+03
# 25%    9.471945e+06
# 50%    1.967728e+07
# 75%    2.915218e+07
# max    3.648724e+07

# %% [markdown]
# ### Dropping unused Columns
#
# - If a column will not be used during machine learning model training, it'd be useful to drop these columns
#
# - Dropping such columns will shrink the size of the dataset and therefore will save from memory

# %%
df.drop(["name", "id", "host_id", "host_name"], inplace=True, axis=1) # dropping the unnecessary columns 
df.head()
# Out:
#   neighbourhood_group  ... availability_365
# 0            Brooklyn  ...              365
# 1           Manhattan  ...              355
# 2           Manhattan  ...              365
# 3            Brooklyn  ...              194
# 4           Manhattan  ...                0
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Outliers Detection
#
# - In most simple terms, an outlier is a data that lies quite far away from the other data points/or is not consistent with the pattern seen in the dataframe
#
# - It can be due to entry errors, or measurement errors, or can even be a natural outlier as well
#
# - The most common method used for detecting the outliers is visualization, and the widely-accepted principle "Outliers lie three or more standard deviation away from the mean." shows us hints on a data point being an outlier

# %% [markdown]
# ### Hero of Outlier Detection: Z-Score
#
# - Z-score is a statistical measurement which indicates how many standard deviations away a given observation is from the mean
#
# - Every single data point has a different Z-score, however, the dataset only has a single mean and a single standard deviation value
#
# ![zsc.png](data:image/png;base64,...)

# %% [markdown]
# #### Imputation

# %% [markdown]
# Imputation is filling missing or outlier values with meaningful data

# %%
integers = ["minimum_nights","number_of_reviews", "calculated_host_listings_count", "availability_365"]

for column in integers:
  df[column] = pd.to_numeric(df[column], errors="coerce")
  
  max_value = (3*df[column].std()) + df[column].mean()  # finds the max value that is not going to be called not an outlier
  min_value = -((3*df[column].std()) + df[column].mean())  # finds the min value that is not going to be called not an outlier

  mean = df.loc[(df[column] > min_value) & (df[column] < max_value), column].mean()  # calculate the new mean of the column without the outlier values

  # if there is no outlier value then the mean will be np.nan in this situation don't need to do imputation
  if mean is not np.nan:  
    df.loc[(df[column] < min_value) | (df[column] > max_value), column] = mean  # change outlier values with mean
    df[column].fillna(mean, inplace=True)  # also fill nan values with mean
  else:  # this condition means there is no outlier value in the column
    df[column].fillna(df[column].mean(), inplace=True)  # just fill nan values with mean

  df[column] = df[column].astype("int64")  # the type will be converted to int64

# %%
sns.histplot(df["price"], kde=True)  #the x-axis's readibility is low, as there are string values in dataset

# %%
floats = ["price", "reviews_per_month", "calculated_host_listings_count", "latitude", "longitude"]

for column in floats:
  df[column] = pd.to_numeric(df[column], errors="coerce")
  
  max_value = (3*df[column].std()) + df[column].mean()  # finds the max value that is not going to be called not an outlier
  min_value = -((3*df[column].std()) + df[column].mean())  # finds the min value that is not going to be called not an outlier

  mean = df.loc[(df[column] > min_value) & (df[column] < max_value), column].mean()  # calculate the new mean of the column without the outlier values

  # if there is no outlier value then the mean will be np.nan in this situation don't need to do imputation
  if mean is not np.nan:  
    df.loc[(df[column] < min_value) | (df[column] > max_value), column] = mean  # change outlier values with mean
    df[column].fillna(mean, inplace=True)  # also fill nan values with mean
  else:  # this condition means there is no outlier value in the column
    df[column].fillna(df[column].mean(), inplace=True)  # filling NA values with mean

  df[column] = df[column].astype("float64") #converting the type to int64

# %%
sns.histplot(df["price"], kde=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  float64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   date                            38857 non-null  object
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  float64
#  11  availability_365                48895 non-null  int64
# ...

# %% [markdown]
# ## Handling missing categorical values

# %%
df.groupby("room_type")["room_type"].value_counts()  # .value_counts() is used to see the values in column "room_type"
# Out:
# room_type     room_type
# -73.78175     -73.78175           1
# -73.7823      -73.7823            1
# -73.78237     -73.78237           1
# -73.78275     -73.78275           1
# -73.7961      -73.7961            1
#                               ...
# Erin V.       Erin V.             1
# Private room  Private room    22287
# Shared room   Shared room      1148
# South Slope   South Slope         1
# Sunnyside     Sunnyside           1
# Name: room_type, Length: 85, dtype: int64

# %%
for key, value in df.groupby(by="room_type")["room_type"].value_counts().items():  # the items that are so rare in the column will be changed to "unknown_type" 
  if value == 1: 
    df.loc[df["room_type"]==key[0], "room_type"] = "unknown_type"  # assigning them as "unknown_type"
    
df.groupby(by="room_type")["room_type"].value_counts()
# Out:
# room_type        room_type
# Entire home/apt  Entire home/apt    25378
# Private room     Private room       22287
# Shared room      Shared room         1148
# unknown_type     unknown_type          82
# Name: room_type, dtype: int64

# %%
df.isna().sum()  # prints the number of NA values for each column
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# date                              10038
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.loc[df.isna()["date"], "date"] = "unknown_date"  # assigning NAs of the date column to "unknown_type"

# %%
df.isna().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# date                              0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## Converting dtypes

# %%
object_columns = df.select_dtypes("object").columns  
object_columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'date'], dtype='object')

# %%
for column in object_columns:
  df[column] = df[column].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  category
#  1   neighbourhood                   48895 non-null  category
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  category
#  5   price                           48895 non-null  float64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   date                            48895 non-null  category
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  float64
#  11  availability_365                48895 non-null  int64
# ...

# %%
df.describe().T  # describe gives basic statistics for each column if the column is of dtype such as float or int64
# Out:
#                                   count        mean  ...         75%        max
# latitude                        48895.0   40.728759  ...   40.762945   40.89245
# longitude                       48895.0  -73.790339  ...  -73.936125   40.86317
# price                           48895.0  138.757449  ...  175.000000  860.00000
# minimum_nights                  48895.0    5.937621  ...    5.000000   76.00000
# number_of_reviews               48895.0   18.148666  ...   20.000000  156.00000
# reviews_per_month               48895.0    1.262339  ...    1.470000    6.43000
# calculated_host_listings_count  48895.0    2.234506  ...    2.000000   34.00000
# availability_365                48895.0  112.601473  ...  226.000000  365.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Pivot Table
#
# - Creates a spreadsheet-style pivot table as a DataFrame

# %%
# ''' 
# df.drop(df.loc[df['room_type']=="unknown_type"].index, inplace=False)["room_type"] :
# drops unknow_type from room_type's and gives remaining room_type's columns to pivot_table as parameter 
# '''
# df.pivot_table(values=["number_of_reviews","availability_365",'price'], 
#                columns=df.drop(df.loc[df['room_type']=="unknown_type"].index, inplace=False)["room_type"],
#                aggfunc=np.mean)
df.pivot_table(values=["number_of_reviews","availability_365",'price'], 
               columns="room_type",
               aggfunc=np.mean)
# Out:
# room_type          Entire home/apt  Private room  Shared room  unknown_type
# availability_365        111.938135    111.202226   161.585366     12.426829
# number_of_reviews        18.300024     18.184053    14.504355     12.707317
# price                   190.426305     83.745606    66.561873    110.431108

# %% [markdown]
# ### Save & Quit
#
# - After preprocessing, don't forget to save dataframe for future use

# %%
df.to_csv("airbnb_nyc_preprocessed.csv")  # turns the dataframe into a csv
